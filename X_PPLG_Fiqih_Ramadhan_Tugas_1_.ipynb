# %% [markdown]
# <a href="https://colab.research.google.com/github/fiqihramadhanf-dotcom/DasarPPLG-X-2627/blob/main/X_PPLG_Fiqih_Ramadhan_Tugas_1_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Tugas 1 Praktik Membuat Tipe Data Dan Variabel
#
# Nama kelompok:iq+kETENANGAN
#
# Nama Anggota:
#
# 1.Fiqih Ramadhan
#
# 2.Syfik Hakim
#
# 3.Habibi Hamka
#
# 4.Rafa Anurwansyah
#
# 5.Satri Apriliansyah

# %%
# %%writefile praktik_variabel.cpp
# #include <iostream>
# #include <string>
# using namespace std;
#
# int main() {
#     // Deklarasi Variabel dan Tipe Data
#     string namaBarang = "Iphone Kupih";
#     string kategori = "ELEKTRONIK";
#     int jumlah = 2;
#     float harga = 7000000.50;
#     bool tersedia = true;
#
#     // Menampilkan Output ke Layar
#     cout << "=== DATA INVENTARIS ===" << endl;
#     cout << "Nama Barang : " << namaBarang << endl;
#     cout << "Kategori    : " << kategori << endl;
#     cout << "Jumlah      : " << jumlah << endl;
#     cout << "Harga       : Rp50000.60 " << harga << endl;
#     cout << "Tersedia    : " << tersedia << " (1 = Ya, 0 = Tidak)" << endl;
#     cout << "=======================" << endl;
#
#     return 0;
# }
# Out:
# Overwriting praktik_variabel.cpp

# %%
# !g++ praktik_variabel.cpp -o praktik_variabel
# !./praktik_variabel
# Out:
# === DATA INVENTARIS ===
# Nama Barang : Iphone Kupih
# Kategori    : ELEKTRONIK
# Jumlah      : 2
# Harga       : Rp50000.60 7e+06
# Tersedia    : 1 (1 = Ya, 0 = Tidak)
# ...
