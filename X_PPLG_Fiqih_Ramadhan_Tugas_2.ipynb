# %% [markdown]
# <a href="https://colab.research.google.com/github/fiqihramadhanf-dotcom/DasarPPLG-X-2627/blob/main/X_PPLG_Fiqih_Ramadhan_Tugas_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Tugas 1 Praktik Membuat Tipe Data Dan Variabel
#
# Nama kelompok:iq+kETENANGAN
#
# Nama Anggota:
#
# 1.fiqih ramadhan
#
# 2.syfik hakim
#
# 3.habibi hamka
#
# 4.rafa anurwansyah
#
# 5.satri apriliansyah

# %%
# %%writefile input_data.cpp
# #include <iostream>
# #include <string>
# using namespace std;
#
# int main() {
#     string namaSiswa;
#     int umur;
#
#     cout<<"Masukkan Nama(1 Kata):";
#     cin>>namaSiswa;
#
#     cout<<"Masukkan Umur Anda :";
#     cin>>umur;
#
#     cout<<"\nhalo "  << namaSiswa <<  ", ternyata umur kamu " << umur << " tahun ya!"
#      << endl;
# return 0;
# }
# Out:
# Overwriting input_data.cpp

# %%
# !g++ input_data.cpp -o input_data

# %%
# !./input_data
